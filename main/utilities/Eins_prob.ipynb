# %%
colors = ["white", "red", "green", "yellow", "blue"]
nationalities = ["English", "German", "Swedish", "Danish", "Norweigan"]
pets = ["dog", "cat", "bird", "horse", "fish"]
cigarettes = ["pall_mall", "dunhill", "blends", "blue_master", "prince"]
drink = ["water", "tea", "coffee", "milk", "juice"]
house_orders = [1, 2, 3, 4, 5]

# %%
class House:
    def __init__(self, color, nationality, cigarette, pet, drink):
        self.color = color
        self.nationality = nationality
        self.cigarette = cigarette
        self.pet = pet
        self.drink = drink

# %%
danish = House(nationality="Danish")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 danish = House(nationality="Danish")
#
# TypeError: House.__init__() missing 4 required positional arguments: 'color', 'cigarette', 'pet', and 'drink'
