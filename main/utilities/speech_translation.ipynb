# %%
import os, re
import whisper
import torch
from pprint import pprint
# from main.utilities.pre_post_text_processing import modify_translation, preprocess_text, analyse_text, postprocess_text
# from main.utilities.argos import translate
# from TTS.api import TTS
# import tempfile
# import torchaudio
# from pydub import AudioSegment
# from main.models import *

# %%
import re

def modify_translation(text):
    pattern = r'(?<!^)(?<=\n)(\d+\.)\s*\d+\.?'
    modified_text = re.sub(pattern, r'\1', text)
    return modified_text


def preprocess_text(text):
    preprocessed_text = re.sub(r'(\d+)-', r'\1.', text)
    return preprocessed_text


def single_word_input(text):
    return len(text.split()) == 1


def analyse_text(text):
    analysis_result = dict()
    single_word = single_word_input(text)

    analysis_result["single_word"] = single_word
    return analysis_result


def postprocess_text(translation, source_text_analysis):
    for i in range(5):
        translation = modify_translation(translation)

    if source_text_analysis["single_word"]:
        translated_words_list = translation.split()
        if (len(translated_words_list) > 1) and (set([translated_words_list[0]]) == set(translated_words_list)):
            translation = translated_words_list[0]
    return translation

# %%
import argostranslate.translate

# Persian 
def translate_en_fa(article_en):
    result = argostranslate.translate.translate(article_en, 'en', 'fa',)
    return result


def translate_fa_en(article_fa):
    result = argostranslate.translate.translate(article_fa, 'fa', 'en',)
    result = result.replace('&quot; ', '')
    result = result.replace(' &apos; ', "'")
    return result


# Arabic
def translate_ar_en(article_ar):
    result = argostranslate.translate.translate(article_ar, 'ar', 'en',)
    result = result.replace('&quot; ', '')
    result = result.replace(' &apos; ', "'")

    return result


def translate_en_ar(article_en):
    article_en = article_en.replace('(', '')
    article_en = article_en.replace(')', '')
    result = argostranslate.translate.translate(article_en, 'en', 'ar',)
    result = result.replace('&quot; ', '')

    return result


def translate_fa_ar(article_fa):
    article_en = translate_fa_en(article_fa)
    result = translate_en_ar(article_en)
    return result


def translate_ar_fa(article_ar):
    article_en = translate_ar_en(article_ar)
    result = translate_en_fa(article_en)
    return result


# Deutsch
def translate_en_de(article_en):
    result = argostranslate.translate.translate(article_en, 'en', 'de',)
    return result

def translate_de_en(article_de):
    result = argostranslate.translate.translate(article_de, 'de', 'en',)
    return result


# Hebrew
def translate_en_he(article_en):
    result = argostranslate.translate.translate(article_en, 'en', 'he',)
    return result

def translate_he_en(article_en):
    result = argostranslate.translate.translate(article_en, 'he', 'en',)
    return result

def translate_he_fa(article_he):
    article_en = translate_he_en(article_he)
    result = translate_en_fa(article_en)
    return result

def translate_fa_he(article_fa):
    article_en = translate_fa_en(article_fa)
    result = translate_en_he(article_en)
    return result

def translate_he_ar(article_he):
    article_en = translate_he_en(article_he)
    result = translate_en_ar(article_en)
    return result

def translate_ar_he(article_ar):
    article_en = translate_ar_en(article_ar)
    result = translate_en_he(article_en)
    return result




def translate(article, source_lang, target_lang):
    if source_lang == 'en' and target_lang == 'fa':
        return translate_en_fa(article)
    elif source_lang == 'fa' and target_lang == 'en':
        return translate_fa_en(article)
    elif source_lang == 'ar' and target_lang == 'en':
        return translate_ar_en(article)
    elif source_lang == 'en' and target_lang == 'ar':
        return translate_en_ar(article)
    elif source_lang == 'fa' and target_lang == 'ar':
        return translate_fa_ar(article)
    elif source_lang == 'ar' and target_lang == 'fa':
        return translate_ar_fa(article)
    elif source_lang == 'en' and target_lang == 'de':
        return translate_en_de(article)
    elif source_lang == 'de' and target_lang == 'en':
        return translate_de_en(article)
    elif source_lang == 'he' and target_lang == 'en':
        return translate_he_en(article)
    elif source_lang == 'en' and target_lang == 'he':
        return translate_en_he(article)
    elif source_lang == 'he' and target_lang == 'fa':
        return translate_he_fa(article)
    elif source_lang == 'fa' and target_lang == 'he':
        return translate_fa_he(article)
    elif source_lang == 'he' and target_lang == 'ar':
        return translate_he_ar(article)
    elif source_lang == 'ar' and target_lang == 'he':
        return translate_ar_he(article)
    else:
        return "Invalid input"

# %%
def speech_to_text(file_path, lang):
    model = whisper.load_model("medium")
    result = model.transcribe(file_path, language=lang)
    transcription = result["text"]
    return transcription

# %%
LANG = "fa"
speech_path_30s = r"C:\Users\User_1\Desktop\spch_30s.mp3"
speech_path_1m = r"C:\Users\User_1\Desktop\spch_1m.mp3"
speech_path_2m = r"C:\Users\User_1\Desktop\spch_2m.mp3"
speech_path_najma_105s = r"C:\Users\User_1\Desktop\Najma_105s.mp3"

# transcription_30s = speech_to_text(speech_path_30s, LANG)
# transcription_1s = speech_to_text(speech_path_1m, LANG)
# transcription_2m = speech_to_text(speech_path_2m, LANG)
transcription_najma_105s = speech_to_text(speech_path_najma_105s, LANG)

# %%
pprint(transcription_2m)
print(len(transcription_2m))
# Out:
# (' خلاص این تادگاه شروع می شو و نکسون هم دور دقومش و تازه شروع کرده یه '
#  'تغییراتی داره اینجا اونجا می دهی یه جایی که می خواه تغییر بده سیاییه چون اون '
#  'همکاری رو که می خواسته از سیاییه نگرفته ندیده یه خود رابطه رابطش با سیاییه و '
#  'FBI جالبم هست خودشون مستقیم با اینا دعیل نکرده اصلا صحبت کردن با روحسای '
#  'سازمان های اطلاعاتی اینکار یه حوام مقام رئیس FBI و مثلا بورده باشه پانی رئیس '
#  'سیایه همون دور اولم اینکار کرده ولی اول که اومده دور اول این رئیسه رو اواز '
#  'نکرده جالبم هست دولت از دولت دموکرات شده دولت جمهوری خواه ولی رئیس جمهور نه '
#  'رئیس FBI رو اواز کرده نه رئیس سیایه رو که خیلی کار عجبی هم نیست اینا بلخار '
#  'اصلا میگن این پسط سیاسی حساب نمیشن که بخان هزبی باشن رئیس سازمان اطلاعاتی '
#  'نبود در این هزب اون هزب ارتباطی داشته باشه و با هزب این هزب بیاد اون هزب '
#  'بیاد اواز بشه با سر همین نکسون هم اواز نکرده بود بعد سر واترگیت و فشارای '
#  'نکسون و فشار میاد بود که آره سیایه بیاد بگی که این کار امنیت ملیو و FBI رو '
# ...

# %%
pprint(transcription_1m)
print(len(transcription_1m))
# Out:
# (' خلاص این تادگاه شروع می شو و نکسونم دور دقومش و تازه شروع کرده یه تغییراتی '
#  'داره اینجا اونجا می دهی یه جایی که می خواه تغییر بده سیاییه چون اون همکاری '
#  'رو که می خواسته از سیاییه نگرفته ندیده یه خود دوست رابطش با سیاییه و FBI '
#  'جالبم هست خودشون مستقیم با اینها دعیل نکرده اصلا صحبت کردن با رو اصای سازمان '
#  'های اطلاعاتی هم FBI هم CIA رو سپورده دست دفترش اینکار یه حبا مقام رئیس FBI '
#  'هم اصلا بورده باشه پایین رئیس CIA همون دور اولم اینکار کرده ولی اول که اومده '
#  'دور اول این رئیسه رو عوض نکرده جالبم هست دولت از دولت دموکرات شده دولت '
#  'جمهوری خواه ولی رئیس جمهور نه رئیس FBI رو عوض کرده نه رئیس CIA رو که خیلی '
#  'کار عجبی هم نیست اینها بلخر اصلا میگن پست سیاسی حساب نمیشن که بخان هزبی باشن '
#  'رئیس سازمان اتلاعاتی نبود با این هزب اون هزب ارتباطی داشته باشه و با هزب این '
#  'هزبیاد اون هزبیاد اواز بشه')
# 778

# %%
pprint(transcription_30s)
print(len(transcription_30s))
# Out:
# (' خلاص این تادگاه شروع می شو و نکسونم دور دقومش و تازه شروع کرده یه تغییراتی '
#  'داره اینجا اونجا می ده یه جایی که می خواه تغییر بده سیایه اه چون اون همکاری '
#  'رو که می خواسته از سیایه ای نگرفته ندیده یه خود دوست رابطش با سیایه و FBI '
#  'جالبم هست خودشو مستقیم با اینا دعیل نکرد اصلا صحبت کردن با رو اصای سازمان '
#  'های اطلاعاتی هم FBI هم CIA رو سپورده دست دفترش')
# 346

# %%
pprint(transcription_najma_105s)
print(len(transcription_najma_105s))
# Out:
# (' این حرف از دهن دختر اومد بیرون اونها ای که دوروبر پادشا ها جم شده بودن گفتن '
#  'بهتره سر این جوانو زیر آب بکنیم و نظریم از این قصر پا بیرون بزاره و گنه '
#  'آوازش می افت به دهن مردم آبرو شاه و دخترش می ره دختره که دید اینها دارن '
#  'پدرشو شیر می کنن گفت همه دردی دوائی دارد آخر همه شامی سبایی دارد آخر همه بر '
#  'کشتن نجمه رضای این نجمه هم خدایی دارد آخر پادشا داش می جنبید و می خواست '
#  'دستور قتل نجمه رو بده که وزیر پا گذاش جلو رو کرد و پادشا و گفت بهتر خون این '
#  'جوانو به گردن نگیرین در عبز کاری کنیم که از کارش سر بخور و بره رد کار خودش '
#  'شایی که دق کنو جونش دربره پادشا که می دونس این وزیر این بقی پدر سخت نیست و '
#  'عقل دارو و خیر و سلاشم می خواد گفت چکار باید کنیم؟ وزیر گفت پادشا دستور بده '
#  'نجمه رو تو چاہ تاریک بندازن و چل دخترم رخت یکرنگ تنشون بکنن و برن پیش اون و '
#  'از اش بخان تا بگه کدوم دختر پادشا هر اگه درست گفت معلوم می شه جوان مغولیه و '
#  'اگه نه خودش پیش دختر پادشا شرمنده می شه و رااشو می گیر و میره ممرها و نجمه '
# ...

# %%
print(transcription_najma_105s)
# Out:
#  این حرف از دهن دختر اومد بیرون اونها ای که دوروبر پادشا ها جم شده بودن گفتن بهتره سر این جوانو زیر آب بکنیم و نظریم از این قصر پا بیرون بزاره و گنه آوازش می افت به دهن مردم آبرو شاه و دخترش می ره دختره که دید اینها دارن پدرشو شیر می کنن گفت همه دردی دوائی دارد آخر همه شامی سبایی دارد آخر همه بر کشتن نجمه رضای این نجمه هم خدایی دارد آخر پادشا داش می جنبید و می خواست دستور قتل نجمه رو بده که وزیر پا گذاش جلو رو کرد و پادشا و گفت بهتر خون این جوانو به گردن نگیرین در عبز کاری کنیم که از کارش سر بخور و بره رد کار خودش شایی که دق کنو جونش دربره پادشا که می دونس این وزیر این بقی پدر سخت نیست و عقل دارو و خیر و سلاشم می خواد گفت چکار باید کنیم؟ وزیر گفت پادشا دستور بده نجمه رو تو چاہ تاریک بندازن و چل دخترم رخت یکرنگ تنشون بکنن و برن پیش اون و از اش بخان تا بگه کدوم دختر پادشا هر اگه درست گفت معلوم می شه جوان مغولیه و اگه نه خودش پیش دختر پادشا شرمنده می شه و رااشو می گیر و میره ممرها و نجمه رو بردن و در چاہ تاریک انداختن و گفتن الان باید بلائی چاہ رو نگاه کنی و اگه واقعا دختر پادشا رو دوست
# ...

# %%
transcription_najma_105s_refined = "این حرف از دهن دختر اومد بیرون اونهایی که دور و بر پادشاه جمع شده بودند گفتند بهتره سر این جوان رو زیر آب بکنیم و نگذاریم از این قصر پا بیرون بزاره وگرنه آوازه ش می افته به دهن مردم آبروی شاه و دخترش میره دختره که دید اینها دارن پدرشو شیر می کنن گفت همه دردی دوائی دارد آخر همه شامی سبایی دارد آخر همه بر کشتن نجمه رضایند این نجمه هم خدایی دارد آخر. پادشاه داشت می جنبید و می خواست دستور قتل نجمه رو بده که وزیر پا گذاشت جلو رو کرد و پادشاه گفت بهتره خون این جوان رو به گردن نگیرین در عوض کاری کنیم که از کارش سر بخوره و بره رد کار خودش شاید که دق کنه و جونش دربره. پادشاه که می دونست این وزیر این قدری پدر سوخته نیست و عقل دارو و خیر و صلاحش هم می خواد گفت چکار باید کنیم؟ وزیر گفت پادشا دستور بده نجمه رو توی چاہ تاریک بندازند و چهل دختر رخت یکرنگ تنشون بکنند و برن پیش اون و ازش بخوان تا بگه کدوم دختر پادشاه. اگه درست گفت معلوم می شه جوان معقولیه و اگه نه خودش پیش دختر پادشا شرمنده میشه و راهشو میگیر و میره. مامورها نجمه رو بردند و در چاہ تاریکی انداختن و گفتند الان باید بالای چاہ رو نگاه کنی و اگه واقعا دختر پادشاه رو دوست داری و هوس به سرت نزده باید بگی از این چهل دختری که می گذرند کدامشون دختر پادشاه هست. نجمه منتظر ماند و دخترها راه افتادن و از بالای چاہ رد شدند ولی دختر پادشاه سر سنگ بلای چاہ نشست و چادرش رو به دندون گرفت و طوری حرف زد که نجمه بدونه اون نشسته و رد نشده. نجمه از ته چاه گفت مسلمانان دلم تنگی گرفته"
transcription_najma_105s_refined
# Out:
# 'این حرف از دهن دختر اومد بیرون اونهایی که دور و بر پادشاه جمع شده بودند گفتند بهتره سر این جوان رو زیر آب بکنیم و نگذاریم از این قصر پا بیرون بزاره وگرنه آوازه ش می افته به دهن مردم آبروی شاه و دخترش میره دختره که دید اینها دارن پدرشو شیر می کنن گفت همه دردی دوائی دارد آخر همه شامی سبایی دارد آخر همه بر کشتن نجمه رضایند این نجمه هم خدایی دارد آخر. پادشاه داشت می جنبید و می خواست دستور قتل نجمه رو بده که وزیر پا گذاشت جلو رو کرد و پادشاه گفت بهتره خون این جوان رو به گردن نگیرین در عوض کاری کنیم که از کارش سر بخوره و بره رد کار خودش شاید که دق کنه و جونش دربره. پادشاه که می دونست این وزیر این قدری پدر سوخته نیست و عقل دارو و خیر و صلاحش هم می خواد گفت چکار باید کنیم؟ وزیر گفت پادشا دستور بده نجمه رو توی چاہ تاریک بندازند و چهل دختر رخت یکرنگ تنشون بکنند و برن پیش اون و ازش بخوان تا بگه کدوم دختر پادشاه. اگه درست گفت معلوم می شه جوان معقولیه و اگه نه خودش پیش دختر پادشا شرمنده میشه و راهشو میگیر و میره. مامورها نجمه رو بردند و در چاہ تاریکی انداختن و گفتند الان باید بالای چاہ رو نگاه ک
# ...

# %%
source_text_preprocessed = preprocess_text(transcription_najma_105s_refined)
source_text_analysis = analyse_text(transcription_najma_105s_refined)
translation = translate(source_text_preprocessed, LANG, "en")
translation = postprocess_text(translation, source_text_analysis)
translation
# Out:
# 'It came out of the mouth of the girl, who gathered around and over the king, said, "We\'re better at drinking this young man, and we don\'t let him go out of this palace, or his song goes to the mouth of the people of the king\'s honor and his daughter, who saw them, and they\'re all in the last resort to kill him. The king stood up and wanted to order the murder order that the minister had left, and the king said, “It’s better not to take the blood of this young man, instead of doing what he was doing and rejecting his own work, perhaps if he did and his life in the barefoot. The king, who knew that the minister was not so burned, and that the reason for his medicine and his good, would he say what to do? The minister said, “Let’s take the syndicate in Dark Chatch, and 40 girls dress up and go to it and tell him which daughter of the king.” If it is true, the young man will be reasonable and if not, he will be ashamed of himself and his way. The officers took the synam and darkened
# ...

# %%
print(translation)
print(len(translation))
# Out:
# It came out of the mouth of the girl, who gathered around and over the king, said, "We're better at drinking this young man, and we don't let him go out of this palace, or his song goes to the mouth of the people of the king's honor and his daughter, who saw them, and they're all in the last resort to kill him. The king stood up and wanted to order the murder order that the minister had left, and the king said, “It’s better not to take the blood of this young man, instead of doing what he was doing and rejecting his own work, perhaps if he did and his life in the barefoot. The king, who knew that the minister was not so burned, and that the reason for his medicine and his good, would he say what to do? The minister said, “Let’s take the syndicate in Dark Chatch, and 40 girls dress up and go to it and tell him which daughter of the king.” If it is true, the young man will be reasonable and if not, he will be ashamed of himself and his way. The officers took the synam and darkened in C
# ...

# %%
def split_text_for_tts(text, max_length=250):
    # Split by sentence-ending punctuation
    sentences = re.split(r'(?<=[.!?])\s+', text)
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(sentence) > max_length:
            # If a single sentence is too long, split further by commas or other punctuation
            sub_sentences = re.split(r'[,;:"\'()]', sentence)
            for sub in sub_sentences:
                if len(current_chunk) + len(sub) + 1 <= max_length:
                    current_chunk += " " + sub
                else:
                    chunks.append(current_chunk.strip())
                    current_chunk = sub
        else:
            if len(current_chunk) + len(sentence) + 1 <= max_length:
                current_chunk += " " + sentence
            else:
                chunks.append(current_chunk.strip())
                current_chunk = sentence

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

# %%
text_chunks = split_text_for_tts(translation, max_length=250)
print("Number of chunks:", len(text_chunks))
for idx, txt in enumerate(text_chunks):
    txt_length = len(txt)
    print(f"{idx} ({txt_length} chars): {txt}")
# Out:
# Number of chunks: 3
# 0 (205 chars): This is the word of the girl’s mouth  which is better to say to the young man under the water  and we think of the palace  and that he says  “What do you do?” The minister said  “Let me give you a dark hat
# 1 (240 chars): and my daughter wash their clothes and go to her  and tell her what a little girl would say if she didn’t  she would like to tell her that she had to do it  and if she didn’t  she’d like it  and she’d like her  and she didn’t want to say it
# 2 (31 chars): and she didn’t want to see her.

# %%
from TTS.api import TTS
from pydub import AudioSegment

temp_dir = r"C:\Users\Desktop\temp"

def generate_speech(text, lang, output_path, temp_dir):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    if lang in ["en", "ar"]:
        reference_speaker = r"D:\Projects\Offline_translator-webapp\main\utilities\obama.ogg"
        tts = TTS(model_name="tts_models/multilingual/multi-dataset/xtts_v2").to(device)

        text_chunks = split_text_for_tts(text)
        print("\ntext_chunks:\n", text_chunks, "\n\n")
        n_chunks = len(text_chunks)
        file_basename = os.path.basename(output_path)
        temp_files = []

        for i, chunk in enumerate(text_chunks):
            
            temp_file = os.path.join(temp_dir, f"{file_basename}_chunk_{i}.wav")
            tts.tts_to_file(chunk, file_path=temp_file, speaker_wav=reference_speaker, language=lang)
            temp_files.append(temp_file)

            progress = int((i + 1) * 100 / n_chunks)

        # Concatenate audio files
        combined_audio = AudioSegment.empty()
        for temp_file in temp_files:
            combined_audio += AudioSegment.from_wav(temp_file)

        # Save final combined audio
        combined_audio.export(output_path, format="wav")

        # Clean up temp files
        for temp_file in temp_files:
            os.remove(temp_file)

    elif lang == "fa":
        print("\nFarsi TTS not yet supported.\n")

    return
